# %% [markdown]
# <a href="https://colab.research.google.com/github/annatagus/gcolab/blob/main/aula_r_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
library(ggplot2)

# %%
install.packages("skimr")
library(skimr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
TitanicDf <-read.csv("/content/Titanic02.csv")

# %%
head(TitanicDf)
# Out:
#   PassengerId Survived Pclass Name
# 1 892         0        3      Kelly, Mr. James
# 2 893         1        3      Wilkes, Mrs. James (Ellen Needs)
# 3 894         0        2      Myles, Mr. Thomas Francis
# 4 895         0        3      Wirz, Mr. Albert
# 5 896         1        3      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6 897         0        3      Svensson, Mr. Johan Cervin
#   Sex    Age  SibSp Parch Ticket  Fare    Cabin Embarked
# 1 male   34.5 0     0     330911   7.8292       Q
# 2 female 47.0 1     0     363272   7.0000       S
# 3 male   62.0 0     0     240276   9.6875       Q
# 4 male   27.0 0     0     315154   8.6625       S
# 5 female 22.0 1     1     3101298 12.2875       S
# 6 male   14.0 0     0     7538     9.2250       S

# %%
dim(TitanicDf)
# Out:
# [1] 418  12

# %%
summary(TitanicDf)
# Out:
#   PassengerId        Survived          Pclass             Name
#  Min.   : 892.0   Min.   :0.0000   Min.   :1.000   Length   :418
#  1st Qu.: 996.2   1st Qu.:0.0000   1st Qu.:1.000   N.unique :418
#  Median :1100.5   Median :0.0000   Median :3.000   N.blank  :  0
#  Mean   :1100.5   Mean   :0.3636   Mean   :2.266   Min.nchar: 13
#  3rd Qu.:1204.8   3rd Qu.:1.0000   3rd Qu.:3.000   Max.nchar: 63
#  Max.   :1309.0   Max.   :1.0000   Max.   :3.000
#
#         Sex           Age            SibSp            Parch
#  Length   :418   Min.   : 0.17   Min.   :0.0000   Min.   :0.0000
#  N.unique :  2   1st Qu.:21.00   1st Qu.:0.0000   1st Qu.:0.0000
#  N.blank  :  0   Median :27.00   Median :0.0000   Median :0.0000
#  Min.nchar:  4   Mean   :30.27   Mean   :0.4474   Mean   :0.3923
#  Max.nchar:  6   3rd Qu.:39.00   3rd Qu.:1.0000   3rd Qu.:0.0000
#                  Max.   :76.00   Max.   :8.0000   Max.   :9.0000
#                  NAs    :86
# ...

# %%
boxplot(TitanicDf$Age, main="Boxplot de Idade", ylab="Age")
# Out:
# Plot with title “Boxplot de Idade”

# %%
boxplot(TitanicDf$Fare, main="Boxplot de Fare", ylab="Fare")
# Out:
# Plot with title “Boxplot de Fare”

# %%
boxplot(TitanicDf$Fare ~ TitanicDf$Pclass, main="Boxplot de Fare", ylab="Fare")
# Out:
# Plot with title “Boxplot de Fare”

# %%
boxplot(TitanicDf$Age ~ TitanicDf$Pclass, main="Boxplot de Pclass", ylab="Age")
# Out:
# Plot with title “Boxplot de Pclass”
